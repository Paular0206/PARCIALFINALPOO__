# %% [markdown]
# <a href="https://colab.research.google.com/github/Paular0206/PARCIALFINALPOO__/blob/main/parcialfinal_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip install matplotlib

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf_POBLACION_CUNDINAMARCA = gpd.read_file("POBLACION_CUNDINAMARCA.csv")
gdf_POBLACION_CUNDINAMARCA
# Out:
#        f1          f2     f3     f4     f5     f6     f7 objectId codigo_mun  \
# 0   25817   Tocancipá  33677  14449  19228  16817  16860        2      25817
# 1   25823     Topaipí   4504    821   3683   2427   2077        3      25823
# 2   25839       Ubalá  10467   1283   9184   5744   4723        4      25839
# 3   25841      Ubaque   6036    879   5157   3139   2897        5      25841
# 4   25843       Ubate  39205  25532  13673  19085  20120        6      25843
# ..    ...         ...    ...    ...    ...    ...    ...      ...        ...
# 87  25805     Tibacuy   4822    527   4295   2308   2514      115      25805
# 88  25807    Tibirita   2943    494   2449   1496   1447      116      25807
# 89  25815     Tocaima  18601  11073   7528   9400   9201      117      25815
# 90  25200       Cogua  23214   7264  15950  11616  11598      118      25200
# 91  25769  Subachoque  16750   6293  10457   8557   8193      119      25769
#
# ...

# %%
gdf_Municipios_de_Cundinamarca_2022 = gpd.read_file("Municipios_de_Cundinamarca_2022.geojson")
gdf_Municipios_de_Cundinamarca_2022
# Out:
#      OBJECTID MpCodigo       MpNombre      MpArea                    MpNorma  \
# 0         245    25120        Cabrera  421.416402   Ordenanza No. 79 de 1963
# 1         252    25506        Venecia  122.081212                       None
# 2         260    25649   San Bernardo  246.749776                       None
# 3         261    25524          Pandi   71.626785                       None
# 4         272    25053       Arbeláez  142.312248                       None
# ..        ...      ...            ...         ...                        ...
# 111       527    25779           Susa  104.007394                       None
# 112       539    25148      Caparrapí  615.080457                       None
# 113       544    25745       Simijaca   96.580265                       None
# 114       600    25572  Puerto Salgar  515.252722  Ordenanza No. 047 de 1935
# 115       611    25885         Yacopí  955.765644                       None
#
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Convertir la columna 'f3' del DataFrame a tipo int
gdf_POBLACION_CUNDINAMARCA['f3'] = gdf_POBLACION_CUNDINAMARCA['f3'].astype(int)
gdf_POBLACION_CUNDINAMARCA['f3']

# Cargar los datos de población y los límites de los municipios en dos GeoDataFrames
gdf_POBLACION_CUNDINAMARCA = gpd.read_file("POBLACION_CUNDINAMARCA.csv")
gdf_Municipios_de_Cundinamarca_2022 = gpd.read_file("Municipios_de_Cundinamarca_2022.geojson")

# Crear una nueva figura
fig, ax = plt.subplots(figsize=(10, 10))

# Plotear los límites de los municipios
gdf_Municipios_de_Cundinamarca_2022.plot(ax=ax, color='lightgray', edgecolor='black')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plotear los límites de los municipios
gdf_Municipios_de_Cundinamarca_2022.plot(ax=ax, color='lightgray', edgecolor='black')

# Mostrar el mapa
plt.show()

# Plotear los datos de población
gdf_POBLACION_CUNDINAMARCA.plot()

# Añadir título
plt.title('Mapa de Población de los Municipios de Cundinamarca')

# Mostrar el mapa
plt.show()
